# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import Counter
from skimage.color import rgb2lab, deltaE_cie76
import os

# %matplotlib inline

# %%
image = cv2.imread('1_lSvFUirQRKEI1TKN_BBVFA.jpeg')
type_ofimg = type(image)
print("The type of image is",type_ofimg)
shape_ofimg = (image.shape)
print("The shape of image is",shape_ofimg)
# Out:
# The type of image is <class 'numpy.ndarray'>
# The shape of image is (787, 1050, 3)

# %%
plt.imshow(image)

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')

# %%
resized_image = cv2.resize(image, (1200, 600))
plt.imshow(resized_image)

# %%
image = cv2.resize(image, (600, 600), interpolation=cv2.INTER_AREA)
image = image.reshape(image.shape[0] * image.shape[1], image.shape[2])

# %%
clf = KMeans(n_clusters = 3)
labels = clf.fit_predict(image)
# Out:
# [1 1 1 ... 2 2 2]
# 360000

# %%
# Out:
#   File "<ipython-input-54-b07a2add6e3c>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing
